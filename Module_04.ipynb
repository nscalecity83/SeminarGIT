# %% [markdown]
# <a href="https://colab.research.google.com/github/nscalecity83/SeminarGIT/blob/main/Module_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Кочкин С.А.

# %% [markdown]
# # Module_04_01

# %% [markdown]
# ### Задание 1

# %%
print('Hello Word')
# Out:
# Hello Word

# %% [markdown]
# ### Задание 2

# %%
print(4, 8, 15, 16, 23, 42)
# Out:
# 4 8 15 16 23 42

# %% [markdown]
# ### Задание 3

# %%
for i in range(1,8):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# ### Задание 4

# %%
print('Отчет о доходах')
print('1 квартал: 1200000 руб.')
print('2 квартал: 1350000 руб.')
print('3 квартал: 1280000 руб.')
print('4 квартал: 1420000 руб.')
# Out:
# Отчет о доходах
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.

# %% [markdown]
# ### Задание 5

# %%
name = input()
print('Добро пожаловать в команду ', name, '!')
# Out:
# Станислав
# Добро пожаловать в команду  Станислав !

# %% [markdown]
# ### Задание 6

# %%
company_name = input()
print(company_name, ' - лидер рынка!')
# Out:
# ООО "Ромашка"
# ООО "Ромашка"  - лидер рынка!

# %% [markdown]
# ### Задание 7

# %%
report = input()
row_number = input()
col_number = input()
print(report)
print(row_number)
print(col_number)
# Out:
# Sales Q1
# 1000
# 8
# Sales Q1
# 1000
# 8

# %% [markdown]
# ### Задание 8

# %%
rep_1 = input()
rep_2 = input()
rep_3 = input()
print(rep_3)
print(rep_2)
print(rep_1)
# Out:
# Продажи за январь
# Продажи за февраль
# Продажи за март
# Продажи за март
# Продажи за февраль
# Продажи за январь

# %% [markdown]
# ### Задание 9

# %%
base_price = 100
growth_percent = 20
new_price = base_price * (100 +  growth_percent)/100
delta = new_price - base_price
print('new_price = ', new_price)
print('delta = ', delta)
# Out:
# new_price =  120.0
# delta =  20.0

# %% [markdown]
# ### Задание 10

# %%
print('Северный', 'Центральный', 'Южный', sep = '***')
# Out:
# Северный***Центральный***Южный

# %% [markdown]
# ### Задание 11

# %%
name = input()
print('Подключение установлено.', end = ' | ')
print('Добро пожаловать, ', name, '!', end = ' | ')
# Out:
# Влад
# Подключение установлено. | Добро пожаловать,  Влад ! |

# %% [markdown]
# ### Задание 12

# %%
my_sep = ' | '
product_1 = input()
product_2 = input()
product_3 = input()
print(product_1, product_2, product_3, sep = my_sep)
# Out:
# Молоко
# Хлеб
# Сыр
# Молоко | Хлеб | Сыр

# %% [markdown]
# ### Задание 13

# %%
value_str = '42.7'
my_var = float(value_str)
integer_part = int(float(my_var) - float(my_var % 1))
#print (value_str % 1)
print('integer_part = ', integer_part)
# Out:
# integer_part =  42

# %%
#Способ 2
value_str = '42.7'
my_var = float(value_str)
integer_part = int(round(my_var))
#print (value_str % 1)
print('integer_part = ', integer_part)
# Out:
# integer_part =  43

# %% [markdown]
# ### Задание 14

# %%
orders_yesterday = 10
plan = 20
diffrent = abs(orders_yesterday - plan)
print('Абсолютное отклонение от плана равняется ', diffrent)
# Out:
# Абсолютное отклонение от плана равняется  10

# %% [markdown]
# ### Задание 15

# %%
number = []
for i in range(1,6):
  #number[i] = i + 1
  number.append(i)
minim = min(number)
maxim = max(number)
print(f"Наименьшее число {minim} \nНаибольшее число {maxim}")
# Out:
# Наименьшее число 1
# Наибольшее число 5

# %% [markdown]
# ### Задание 16

# %%
first_name = input()
last_name = input()
my_str = 'Привет, ' + first_name + ' ' + last_name + '! Вы только что начали изучать Python'
print(my_str)
# Out:
# Антон
# Иванов
# Привет, Антон Иванов! Вы только что начали изучать Python

# %% [markdown]
# ### Задание 17

# %%
str_1 = input()
str_2 = ', потому что это учит думать."'
str_3 = str_1 + ' потому что это учит думать." '
print(str_3)
# Out:
# «Каждый в этой стране должен научиться программировать,
# «Каждый в этой стране должен научиться программировать, потому что это учит думать."

# %% [markdown]
# ### Задание 18

# %%
amount = int(input ())
print(amount>1000)
# Out:
# 800
# False

# %% [markdown]
# ### Заданте 19

# %%
age = int(input())
print(age>=18b)
# Out:
# 25
# True

# %% [markdown]
# ### Задание 20

# %%
s = float(input())
v1 = float(input())
v2 = float(input())
print(s/(v1+v2))
# Out:
# 500
# 50
# 70
# 4.166666666666667

# %% [markdown]
# ### Задание 21

# %%
a = float(input())
b = float(input())
s = a*b/2
print(s)
# Out:
# 443
# 390
# 86385.0

# %% [markdown]
# ### Задание 22

# %%
temp_f = float(input())
temp_c = 5/9*(temp_f-32)
print(temp_c)
# Out:
# 450.55
# 232.5277777777778

# %% [markdown]
# ### Задание 23

# %%
revenue_str = '438746.78'
bonus_rate = 1
name = 'Антон'
print(f'Курьер {name} получит бонус {round(float(revenue_str)*bonus_rate/100, 0)}р.')
# Out:
# Курьер Антон получит бонус 4387.0р.

# %% [markdown]
# #Module_04_02_1

# %% [markdown]
# ### Задание 1

# %%
my_password = 'qwerty'
def pass_check(my_str = ''):
  if my_str == my_password:
    print('Пароль принят')
  else:
    print('Пароль не принят')

pass_check('qwerty')
pass_check()
pass_check('Qwerty')
# Out:
# Пароль принят
# Пароль не принят
# Пароль не принят

# %% [markdown]
# ### Задание 2

# %%
def check_age(my_age):
  if my_age >= 18:
    print('Доступ разрешен')
  else:
    print('Доступ запрещен')
check_age(17)
check_age(18)
check_age(19)
# Out:
# Доступ запрещен
# Доступ разрешен
# Доступ разрешен

# %% [markdown]
# ### Задание 3

# %%
def my_compare(a, b):
  if a < b:
    print(f'Меньшее число {a}')
  else:
    print(f'Меньшее число {b}')

my_compare(8, 11)
my_compare(11, 8)
# Out:
# Меньшее число 8
# Меньшее число 8

# %% [markdown]
# ### Задание 4

# %%
def check_progression(a, b, c):
  if (a-b) == (b-c):
    print('Это прогрессия')
  else:
    print('Это не прогрессия')

check_progression(1, 2, 3)
check_progression(1, 3, 5)
check_progression(1, 3, 4)
# Out:
# Это прогрессия
# Это прогрессия
# Это не прогрессия

# %% [markdown]
# ### Задание 5

# %%
def check_sales(a, b, c):
  my_sum = 0
  if a > 0:
    my_sum += a
  if b > 0:
    my_sum += b
  if c > 0:
    my_sum += c
  print(f'Result: {my_sum}')

check_sales(-3, -5, -10)
check_sales(5, 4, 3)
check_sales(-3, 4, 3)
# Out:
# Result: 0
# Result: 12
# Result: 7

# %% [markdown]
# ### Задание 6

# %%
def check_min(a, b, c, d):
  try:
    my_min = a
    if b < my_min:
      my_min = b
    if c < my_min:
      my_min = c
    if d < my_min:
      my_min = d
    print(my_min)
  except:
    print('Введите корректные данные!')

check_min(5, 4, 8, 1)
check_min(5, 4, 8, -1)
check_min(5, 4, 0.5, 1)
check_min(5, '4' , 8, 1)
# Out:
# 1
# -1
# 0.5
# Введите корректные данные!

# %% [markdown]
# ### Задание 7

# %%
def check_leap_year(my_year):
  try:
    #if (my_year % 4 == 0 or my_year % 400 == 0) and my_year % 100 != 0:
    if (my_year % 4 == 0 and my_year % 100 != 0) or my_year % 400 == 0:
      print(f'{my_year} - високосный год')
    else:
      print(f'{my_year} - не високосный год')
  except:
    print('Ввведите корректное значение года')

check_leap_year(200)
check_leap_year(2000)
check_leap_year(2009)
check_leap_year(2020)
check_leap_year(1600)
check_leap_year(1700)
check_leap_year('1600')
# Out:
# 200 - не високосный год
# 2000 - високосный год
# 2009 - не високосный год
# 2020 - високосный год
# 1600 - високосный год
# 1700 - не високосный год
# Ввведите корректное значение года

# %% [markdown]
# ### Задание 8

# %%
def fint_median(a, b, c):
  if (a > b and a < c) or (a > c and a < b):
    print(f'{a} - медиана')
  elif (c > b and c < a) or (c > a and c < b):
    print(f'{c} - медиана')
  else:
    print(f'{b} - медиана')

fint_median(1, 2, 3)
fint_median(1, 3, 2)
fint_median(2, 1, 3)
fint_median(2, 3, 1)
fint_median(3, 1, 2)
fint_median(3, 2, 1)
# Out:
# 2 - медиана
# 2 - медиана
# 2 - медиана
# 2 - медиана
# 2 - медиана
# 2 - медиана

# %% [markdown]
# ### Задание 9

# %%
for i in range (10):
  print('Войти в IT с Python')
# Out:
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python

# %% [markdown]
# ### Задание 10

# %%
n = int(input('Введите целое число от 1 до 20'))
for i in range(n):
  print('*' * 19)
# Out:
# Введите целое число от 1 до 203
# *******************
# *******************
# *******************

# %% [markdown]
# ### Задание 11

# %%
def add_index(my_str):
  for i in range(10):
    print(f'{i} {my_str}')

add_index('eposhe')
# Out:
# 0 eposhe
# 1 eposhe
# 2 eposhe
# 3 eposhe
# 4 eposhe
# 5 eposhe
# 6 eposhe
# 7 eposhe
# 8 eposhe
# 9 eposhe

# %% [markdown]
# ### Задание 12

# %%
def fibonacci_num(n):
  j = 0
  k = 0
  #n = 100
  fibonacci_list = []

  #fibonacci_list.append(1)
  #print(fibonacci_list)
  for i in range (n):
    if len(fibonacci_list) < 2:
      fibonacci_list.append(1)
    else:
      fibonacci_list.append(fibonacci_list[i-1]+fibonacci_list[i-2])
  for i in range(len(fibonacci_list)):
    print(f'Элемент {i+1} - {fibonacci_list[i]}')
#fibonacci_num(1)
#fibonacci_num(2)
#fibonacci_num(3)
#fibonacci_num(10)
fibonacci_num(100)
# Out:
# Элемент 1 - 1
# Элемент 2 - 1
# Элемент 3 - 2
# Элемент 4 - 3
# Элемент 5 - 5
# Элемент 6 - 8
# Элемент 7 - 13
# Элемент 8 - 21
# Элемент 9 - 34
# Элемент 10 - 55
# Элемент 11 - 89
# Элемент 12 - 144
# Элемент 13 - 233
# Элемент 14 - 377
# Элемент 15 - 610
# Элемент 16 - 987
# Элемент 17 - 1597
# Элемент 18 - 2584
# Элемент 19 - 4181
# Элемент 20 - 6765
# Элемент 21 - 10946
# Элемент 22 - 17711
# Элемент 23 - 28657
# Элемент 24 - 46368
# Элемент 25 - 75025
# Элемент 26 - 121393
# Элемент 27 - 196418
# Элемент 28 - 317811
# Элемент 29 - 514229
# Элемент 30 - 832040
# Элемент 31 - 1346269
# Элемент 32 - 2178309
# Элемент 33 - 3524578
# Элемент 34 - 5702887
# Элемент 35 - 9227465
# Элемент 36 - 14930352
# Элемент 37 - 24157817
# Элемент 38 - 39088169
# Элемент 39 - 63245986
# Элемент 40 - 102334155
# Элемент 41 - 165580141
# Элемент 42 - 267914296
# Элемент 43 - 433494437
# Элемент 44 - 701408733
# Элемент 45 - 1134903170
# Элемент 46 - 1836311903
# Элемент 47 - 2971215073
# ...

# %% [markdown]
# ### Задание 13

# %%
def my_factorial(n):
  fact = 1
  for i in range(1, n+1):
    fact = fact * i
  print(f'{n}! равен {fact}')
my_factorial(5)
# Out:
# 5! равен 120

# %% [markdown]
# ### Задание 14

# %%
my_log = ['первый', 'второй', 'стоп']
def log_print(my_list):
  i = 0
  while my_list[i] != 'стоп':
    print(my_list[i])
    i += 1

log_print(my_log)
# Out:
# первый
# второй

# %% [markdown]
# ### Задание 15

# %%
def sum_print():
  my_sum = 0
  number = 0
  while number >= 0:
    number = int(input('Введите целое число '))
    if number >= 0:
      my_sum = my_sum + number
  print(f'Сумма чисел равна {my_sum}')

sum_print()
# Out:
# Введите целое число 5
# Введите целое число 5
# Введите целое число -5
# Сумма чисел равна 10

# %% [markdown]
# ### Задание 16

# %%
def triangle_print():
  for i in range(7):
    print('*' *(i+1))
triangle_print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# ### Задание 17

# %%
def print_fio(name, surname, patronymic):
  fio = surname[:1] + name[:1] + patronymic[:1]
  print(fio.upper())

print_fio('Алексей', 'иванов', 'Петрович')
# Out:
# ИАП

# %% [markdown]
# ### Задание 18

# %%
def sqr_sum():
  my_sum = 0
  number = 0
  sum_sqr = 0
  i = 0
  while my_sum != 0 or i == 0:
    number = int(input('Введите целое число '))
    my_sum = my_sum + number
    sum_sqr = sum_sqr + number * number
    i += 1
    print(f'Cумма чисел - {my_sum}')
  print(f'Сумма квадратов - {sum_sqr}')

sqr_sum()
# Out:
# Введите целое число 2
# Cумма чисел - 2
# Введите целое число 2
# Cумма чисел - 4
# Введите целое число -4
# Cумма чисел - 0
# Сумма квадратов - 24

# %% [markdown]
# ### Задание 19

# %%
def km_to_mile(n):
  distans_ml = round(int(n) * 0.6214, 4)
  return distans_ml
print(km_to_mile(10))
# Out:
# 6.214

# %% [markdown]
# # Module_04_03

# %% [markdown]
# ### Задание 1

# %%
def print_list(n):
  my_list = list(range(1, n+1))
  print(my_list)

print_list(5)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Задание 2

# %%
user_ids = [104, 217, 86, 395, 132]
def user_ids_info(user_list):
  total_users = len(user_ids)
  min_max_ids = []
  min_max_ids.append(min(user_ids))
  min_max_ids.append(max(user_ids))
  ID_second_user = user_list[1]
  last_user = user_list[-1]

  print(total_users)
  print(min_max_ids)
  print(ID_second_user)
  print(last_user)

user_ids_info(user_ids)
# Out:
# 5
# [86, 395]
# 217
# 132

# %% [markdown]
# ### Задание 3

# %%
moscow_orders = [104, 217, 86, 395, 132]
spb_orders = [120, 205, 180, 260, 155]
def orders_check(mos, spb):
  total_moscow = sum(mos)
  total_spb = sum(spb)
  all_orders_desc = sorted(mos + spb, reverse = True)
  max_single_day = max(all_orders_desc)
  average_moscow = int(round(sum(mos)/len(mos), 0))
  had_zero_moscow = 0 in mos

  print(total_moscow)
  print(total_spb)
  print(all_orders_desc)
  print(max_single_day)
  print(average_moscow)
  print(had_zero_moscow)


orders_check(moscow_orders, spb_orders)
# Out:
# 934
# 920
# [395, 260, 217, 205, 180, 155, 132, 120, 104, 86]
# 395
# 187
# False

# %% [markdown]
# ### Задание 4

# %%
events = ["Поиск", "Настройки", "Профиль"]
important_sections = ["Главная", "Каталог"]

def events_list (events, imp_sect):
  events.insert(0, imp_sect[0])
  events.append(imp_sect[1])
  events.remove('Профиль')
  print(events)

events_list(events, important_sections)
# Out:
# ['Главная', 'Поиск', 'Настройки', 'Каталог']

# %% [markdown]
# ### Задание 5

# %%
ratings = [5, 4, 3, 5, 5, 2, 4, 5]

def ratings_check(ratings):
  count_fives = ratings.count(5)
  share_of_fives = round(count_fives/len(ratings), 1)

  print(f'Количество оценок "5": {count_fives}')
  print(f'Доля оценок "5": {share_of_fives}')

ratings_check(ratings)
# Out:
# Количество оценок "5": 4
# Доля оценок "5": 0.5

# %% [markdown]
# ### Задание 6

# %%
session_durations = [15, 40, 1, 25, 5]

def session_info(session):
  shortest_session = min(session)
  session.insert(0, 0)
  session.sort()
  is_long_session = True if len(session) > 5 else False


  print(f'Самая короткая сессия: {shortest_session}')
  print(f'Обновленный список: {session})')
  print(f'Короткая ли сессия? {is_long_session}')

session_info(session_durations)
# Out:
# Самая короткая сессия: 1
# Обновленный список: [0, 1, 5, 15, 25, 40])
# Короткая ли сессия? True

# %% [markdown]
# ### Задание 7

# %%
def list_of_cubes():
  cubes = []
  try:
    n = int(input('Введите количество элементов '))
    for i in range(n):
      elem = int(input('Введите элемент: '))
      cubes.append(pow(elem, 3))
    print(f'Список кубов {cubes}')
  except:
    print('Введите целое число')
list_of_cubes()
# Out:
# Введите количество элементов 5
# Введите элемент: 1
# Введите элемент: 2
# Введите элемент: 3
# Введите элемент: 4
# Введите элемент: 5
# Список кубов [1, 8, 27, 64, 125]

# %% [markdown]
# ### Задание 8

# %%
numbers = (3.1415, 1.8, 1.9, 1.4, 1.161, 1.324)

def turple_min_max(turp):
  my_var = max(turp) + min(turp)

  print(f'Сумма минимально и максимального элемента: {my_var}')

turple_min_max(numbers)
# Out:
# Сумма минимально и максимального элемента: 4.3025

# %% [markdown]
# ### Задание 9

# %%
employee = ('Иванов Иван', 1985, 'СанктПетербург')
def check_employee(emp):
  new_turple = list(emp)
  new_turple[-1] = 'Москва'
  new_turple = tuple(new_turple)
  print(f'Новый кортеж: {new_turple}')

check_employee(employee)
# Out:
# Новый кортеж: ('Иванов Иван', 1985, 'Москва')

# %% [markdown]
# ### Задание 10

# %%
courier = {
  'name': 'Иван',
  'delivered_orders': 125,
  'is_active': True
}
print(f'Словарь: {courier}')
# Out:
# Словарь: {'name': 'Иван', 'delivered_orders': 125, 'is_active': True}

# %% [markdown]
# ### Задание 11

# %%
products = {
 'стол': 'мебель',
 'диван': 'мебель',
 'лампа': 'дом',
 'холодильник': 'техника'
}

def check_dict(prod):
  if 'дом' in prod.values():
    print('True')
  else:
    print('False')

check_dict(products)
# Out:
# True

# %% [markdown]
# ### Задание 12

# %%
products = {
 'стол': 'мебель',
 'диван': 'мебель',
 'лампа': 'дом',
 'холодильник': 'техника'
}

def uniqe_cat(prod):
  my_values = prod.values()
  uniqe = list(set(my_values))
  products_number = len(prod)
  print(f'Уникальные категории: {uniqe}')
  print(f'Число товаров: {products_number}')


uniqe_cat(products)
# Out:
# Уникальные категории: ['техника', 'дом', 'мебель']
# Число товаров: 4

# %% [markdown]
# ### Задание 13

# %%
products = {
 'стол': 'мебель',
 'диван': 'мебель',
 'лампа': 'дом',
 'холодильник': 'техника'
}

def products_names(prod):
  product_names = sorted(list(prod.keys()))
  first_product = product_names[0]
  print(f'Список товаров в алфавитном порядке: {product_names}')
  print(f'Первый в списке: {first_product}')

products_names(products)
# Out:
# Список товаров в алфавитном порядке: ['диван', 'лампа', 'стол', 'холодильник']
# Первый в списке: диван

# %% [markdown]
# ### Задание 14

# %%
user_data = {
  'orders_count': 4,
  'total_spent': 6000
}

def check_clint(user):
  if (user['orders_count'] > 5) & (user['total_spent'] > 10000):
    print('Хороший клиент')
  elif (user['orders_count'] > 3) & (user['total_spent'] > 5000):
    print('Хороший клиент')
  else:
    print('Обычный клиент')


check_clint(user_data)
# Out:
# Хороший клиент

# %% [markdown]
# ### Задание 15

# %%
my_string = 'analytics'

def uniqe_sym(sym):
  un = set(sym)
  print(sorted(un))

uniqe_sym(my_string)
# Out:
# ['a', 'c', 'i', 'l', 'n', 's', 't', 'y']

# %% [markdown]
# ### Задание 16

# %%
string_1 = 'abc'
string_2 = 'cab'
string_3 = 'bac'

def comparison_string(str_1, str_2, str_3):
  if sorted(set(str_1)) == sorted(set(str_2)) ==sorted(set(str_3)):
    print('Да')
  else:
    print('Нет')

comparison_string(string_1, string_2, string_3)
# Out:
# Да

# %% [markdown]
# ### Задание 17

# %%
my_string = '1 2 3 4 1'
def check_elem(str):
  list_sym = str.split(' ')
  uniqe_sym = set()
  lens_1 = len(uniqe_sym)
  for i in list_sym:
    uniqe_sym.add(i)
    if lens_1 != len(uniqe_sym):
      lens_1 = len(uniqe_sym)
      print('Нет')
    else:
      print('Да')

check_elem(my_string)
# Out:
# Нет
# Нет
# Нет
# Нет
# Да

# %% [markdown]
# ### Задание 18

# %%
def lens_of_string():
  number = int(input('Введите количество строк'))
  my_list = []
  for i in range(number):
    my_string = input('Введите слово: ')
    my_list.append(len(set(my_string)))
  print(my_list)

lens_of_string()
# Out:
# Введите количество строк3
# Введите слово: 2
# Введите слово: Андрей
# Введите слово: 123123
# [1, 6, 3]

# %% [markdown]
# # Module_04_04

# %% [markdown]
# ### Задание 1

# %%
import pandas as pd
import numpy as np

# %%
data = {
  'сотрудник': ['Алина', 'Борис', 'Владимир', 'Дарья', 'Егор', 'Федор',
  'Галина', 'Наталья', 'Игорь', 'Юлия'],
  'отдел': ['Аналитика', 'Аналитика', 'Маркетинг', 'Аналитика', 'Маркетинг',
  'Аналитика', 'Маркетинг', 'Аналитика', 'Маркетинг', 'Аналитика'],
  'проект_баллы': [85, 92, 78, np.nan, 88, 75, 95, np.nan, 82, 90],
  'выполнено_задач': [5, 7, 6, 7, 5, 6, 8, 4, 5, 7],
  'пройдено_тест': ['да', 'да', 'нет', 'да', 'да', 'нет', 'да', 'нет', 'да',
  'да']
}

labels = ['с1','с2','с3','с4','с5','с6','с7','с8','с9','с10']

df_sotrudniki = pd.DataFrame(data, index = labels)
df_sotrudniki
# Out:
#     сотрудник      отдел  проект_баллы  выполнено_задач пройдено_тест
# с1      Алина  Аналитика          85.0                5            да
# с2      Борис  Аналитика          92.0                7            да
# с3   Владимир  Маркетинг          78.0                6           нет
# с4      Дарья  Аналитика           NaN                7            да
# с5       Егор  Маркетинг          88.0                5            да
# с6      Федор  Аналитика          75.0                6           нет
# с7     Галина  Маркетинг          95.0                8            да
# с8    Наталья  Аналитика           NaN                4           нет
# с9      Игорь  Маркетинг          82.0                5            да
# с10      Юлия  Аналитика          90.0                7            да

# %% [markdown]
# ### Задание 3

# %%
df_sotrudniki.head(3)
# Out:
#    сотрудник      отдел  проект_баллы  выполнено_задач пройдено_тест
# с1     Алина  Аналитика          85.0                5            да
# с2     Борис  Аналитика          92.0                7            да
# с3  Владимир  Маркетинг          78.0                6           нет

# %% [markdown]
# ### Задание 4

# %%
df_sotrudniki.loc[['с4', 'с5', 'с6'], ['сотрудник', 'проект_баллы']]
# Out:
#    сотрудник  проект_баллы
# с4     Дарья           NaN
# с5      Егор          88.0
# с6     Федор          75.0

# %% [markdown]
# ### Задание 5

# %%
df_sotrudniki.loc[df_sotrudniki['выполнено_задач'] > 6]
# Out:
#     сотрудник      отдел  проект_баллы  выполнено_задач пройдено_тест
# с2      Борис  Аналитика          92.0                7            да
# с4      Дарья  Аналитика           NaN                7            да
# с7     Галина  Маркетинг          95.0                8            да
# с10      Юлия  Аналитика          90.0                7            да

# %% [markdown]
# ### Задание 6

# %%
df_sotrudniki.loc['с6', 'проект_баллы'] = 80
df_sotrudniki
# Out:
#     сотрудник      отдел  проект_баллы  выполнено_задач пройдено_тест
# с1      Алина  Аналитика          85.0                5            да
# с2      Борис  Аналитика          92.0                7            да
# с3   Владимир  Маркетинг          78.0                6           нет
# с4      Дарья  Аналитика           NaN                7            да
# с5       Егор  Маркетинг          88.0                5            да
# с6      Федор  Аналитика          80.0                6           нет
# с7     Галина  Маркетинг          95.0                8            да
# с8    Наталья  Аналитика           NaN                4           нет
# с9      Игорь  Маркетинг          82.0                5            да
# с10      Юлия  Аналитика          90.0                7            да

# %% [markdown]
# ### Задание 7

# %%
print(df_sotrudniki['выполнено_задач'].sum())
# Out:
# 60

# %% [markdown]
# ### Задание 8

# %%
df_sotrudniki.groupby('отдел')['проект_баллы'].mean()
# Out:
# отдел
# Аналитика    86.75
# Маркетинг    85.75
# Name: проект_баллы, dtype: float64

# %% [markdown]
# ### Задание 9

# %%
df_sotrudniki_sort = df_sotrudniki.sort_values(by = ['проект_баллы', 'выполнено_задач'], ascending=[False, True])
df_sotrudniki_sort
# Out:
#     сотрудник      отдел  проект_баллы  выполнено_задач пройдено_тест
# с7     Галина  Маркетинг          95.0                8            да
# с2      Борис  Аналитика          92.0                7            да
# с10      Юлия  Аналитика          90.0                7            да
# с5       Егор  Маркетинг          88.0                5            да
# с1      Алина  Аналитика          85.0                5            да
# с9      Игорь  Маркетинг          82.0                5            да
# с6      Федор  Аналитика          80.0                6           нет
# с3   Владимир  Маркетинг          78.0                6           нет
# с8    Наталья  Аналитика           NaN                4           нет
# с4      Дарья  Аналитика           NaN                7            да

# %% [markdown]
# ### Задание 10

# %%
df_sotrudniki['пройдено_тест'] = df_sotrudniki['пройдено_тест'].replace({'да': True, 'нет': False})
df_sotrudniki
# Out:
# /tmp/ipython-input-3539243324.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_sotrudniki['пройдено_тест'] = df_sotrudniki['пройдено_тест'].replace({'да': True, 'нет': False})
#     сотрудник      отдел  проект_баллы  выполнено_задач  пройдено_тест
# с1      Алина  Аналитика          85.0                5           True
# с2      Борис  Аналитика          92.0                7           True
# с3   Владимир  Маркетинг          78.0                6          False
# с4      Дарья  Аналитика           NaN                7           True
# с5       Егор  Маркетинг          88.0                5           True
# с6      Федор  Аналитика          80.0                6          False
# ...

# %% [markdown]
# ### Задание 11

# %%
from sklearn.datasets import fetch_california_housing

# %%
california = fetch_california_housing()

df_california = pd.DataFrame(california.data, columns = california.feature_names)
df_california.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# ### Задание 12

# %%
# Создаем вспомогательный DataFrame с значением медианной стоимостью дома
df_cal_med_house = pd.DataFrame(california.target, columns = california.target_names)
df_cal_med_house.head(5)
# Out:
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
#Соединяем DataFrames
df_california = pd.concat([df_california, df_cal_med_house], axis = 1)
df_california.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# ### Задание 13

# %%
df_california.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# ### Задание 14

# %%
df_california.isna().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# ### Задание 15

# %%
df_cal_filt =df_california.loc[(df_california['HouseAge'] > 50) & (df_california['Population'] > 2500)]
df_cal_filt
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population    AveOccup  \
# 460    1.4012      52.0  3.105714   1.060000      3337.0    9.534286
# 4131   3.5349      52.0  4.646119   1.047945      2589.0    5.910959
# 4440   2.6806      52.0  4.806283   1.057592      3062.0    4.007853
# 5986   1.8750      52.0  4.500000   1.206349      2688.0   21.333333
# 7369   3.1901      52.0  4.730942   1.017937      3731.0    4.182735
# 8227   2.3305      52.0  3.488860   1.170380      3018.0    3.955439
# 13034  6.1359      52.0  8.275862   1.517241      6675.0  230.172414
# 15634  1.8295      52.0  2.628169   1.053521      2957.0    4.164789
# 15652  0.9000      52.0  2.237474   1.053535      3260.0    2.237474
# 15657  2.5166      52.0  2.839075   1.184049      3436.0    1.621520
# 15659  1.7240      52.0  2.278566   1.082348      4518.0    1.780142
# 15795  2.5755      52.0  3.402576   1.058776      2619.0    2.108696
# 15868  2.8135      52.0  4.584329   1.041169      2987.0    3.966799
#
# ...

# %% [markdown]
# ### Задание 16

# %%
print(f'Максимальная медианная стоимость дома: {df_california['MedHouseVal'].max()}')
print(f'Минимальная медианная стоимость дома: {df_california['MedHouseVal'].min()}')
# Out:
# Максимальная медианная стоимость дома: 5.00001
# Минимальная медианная стоимость дома: 0.14999
